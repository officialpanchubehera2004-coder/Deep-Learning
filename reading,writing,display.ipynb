# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"E:\Deeplearning\tensorflow_keras\testing\images (1).jpg")

# %%
input
# Out:
# array([[[ 31,  73,  42],
#         [ 31,  73,  42],
#         [ 31,  73,  42],
#         ...,
#         [ 59, 141, 106],
#         [ 56, 138, 103],
#         [ 54, 136, 101]],
#
#        [[ 30,  72,  41],
#         [ 31,  73,  42],
#         [ 31,  73,  42],
#         ...,
#         [ 49, 131,  96],
#         [ 47, 129,  94],
#         [ 46, 128,  93]],
#
#        [[ 30,  72,  41],
#         [ 30,  72,  41],
#         [ 31,  73,  42],
#         ...,
#         [ 44, 124,  89],
#         [ 43, 123,  88],
#         [ 42, 122,  87]],
#
#        ...,
#
#        [[162, 154, 125],
#         [113, 105,  76],
#         [ 97,  86,  59],
#         ...,
#         [ 31,  28,  13],
#         [ 31,  28,  13],
#         [ 31,  28,  13]],
#
#        [[160, 152, 123],
#         [112, 104,  75],
#         [ 97,  86,  59],
#         ...,
#         [ 30,  27,  12],
#         [ 30,  27,  12],
#         [ 31,  28,  13]],
#
#        [[159, 151, 122],
#         [111, 103,  74],
#         [ 98,  87,  60],
#         ...,
#         [ 30,  27,  12],
#         [ 30,  27,  12],
#         [ 31,  28,  13]]], shape=(447, 447, 3), dtype=uint8)

# %%
cv2.imshow('babu',input)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print('Height of Image:', int(input.shape[0]),'pixels')
print('Width of Image:', int(input.shape[1]),'pixels')

# %%
cv2.imwrite('output.png',input)
